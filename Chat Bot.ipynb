# %%
import random
responses = {
    "hi": ["Hello!", "Hi there!", "Hi, how can I help you?"],
    "hello": ["Hello!", "Hi there!", "Hi, how can I assist you?"],
    "hey": ["Hey there!", "Hello!", "Hi! How can I help you today?"],
    "how are you": ["I'm doing well, thank you. How can I assist you today?", "I'm good, thanks for asking. What can I help you with?"],
    "what's up": ["Not much, how can I assist you today?", "Just here to help. What can I do for you?"],
    "what can you do": ["I can help answer your questions, provide information, and assist with various tasks. What can I help you with today?"],
    "who are you": ["I am a chatbot designed to assist with your needs. How can I help you today?"],
    "where are you from": ["I was created by a team of developers to assist with your needs. How can I assist you today?"],
    "what do you know": ["I know a lot about various topics, including technology, health, and entertainment. What can I help you with?"],
    "how old are you": ["I was just recently created, so I don't have an age yet. How can I assist you today?"],
    "what is your name": ["My name is ChatBot. How can I assist you today?", "I'm ChatBot. What can I help you with?"],
    "can you help me": ["Of course! What can I help you with today?"],
    "what do you do": ["I'm here to help answer your questions and assist with various tasks. What can I help you with today?"],
    "do you have a personality": ["I don't have a personality, but I'm here to assist with your needs. What can I help you with today?"],
    "can you give me advice": ["Sure, what kind of advice are you looking for?"],
    "what is your purpose": ["My purpose is to assist with your needs and answer your questions. How can I help you today?"],
    "what are your skills": ["I'm proficient in answering questions and providing information on various topics. What can I help you with?"],
    "what's new": ["Not much, just here to help. What can I assist you with today?"],
    "what do you recommend": ["It depends on what you're looking for. Can you give me more information?"],
    "what's the weather": ["I'm sorry, I'm not able to provide current weather information. Is there anything else I can help you with?"],
    "what is your favorite color": ["I don't have a favorite color, but I'm here to assist with your needs. What can I help you with today?"],
    "what is your favorite food": ["I don't eat food, but I'm here to assist with your needs. What can I help you with today?"],
    "what is your favorite movie": ["I don't watch movies, but I'm here to assist with your needs. What can I help you with today?"],
    "what iss your favorite song": ["I don't have a favorite song, but I'm here to assist with your needs. What can I help you with today?"],
    "hi": ["Welcome to our restaurant! How can I assist you?"],
    "menu": ["Our menu includes a variety of dishes, such as burgers, pizzas, and salads. Would you like me to recommend anything?"],
    "recommendation": ["Based on your preferences, I would recommend our special burger with fries and a drink."],
    "reservation": ["Sure, let me check availability. How many people will be dining and what time would you like to make a reservation for?"],
    "hours": ["We're open from 11am to 10pm every day."],
    "location": ["We're located at 123 Main Street in Nashik. Can I help with directions?"],
    "thanks": ["You're welcome! Enjoy your meal."],
    "food": ["We use fresh ingredients in all of our dishes to ensure the best quality and taste."],
    "drinks": ["We offer a variety of non-alcoholic and alcoholic drinks, including beer, wine, and cocktails."],
    "dessert": ["Don't forget to save room for dessert! Our most popular desserts are the chocolate cake and the cheesecake."],
    "vegetarian": ["We have several vegetarian options on our menu, including a veggie burger and a garden salad."],
    "gluten-free": ["We also have gluten-free options available, such as a gluten-free pizza crust and a quinoa salad."],
    "kids": ["We have a kids menu with smaller portions and kid-friendly options, such as chicken tenders and mac and cheese."],
    "takeout": ["We offer takeout and delivery options. Would you like to place an order for pickup or delivery?"],
    "payment": ["We accept cash, credit cards, and mobile payments such as Apple Pay and Google Wallet."],
    "wifi": ["Yes, we have free Wi-Fi available for our customers."],
    "default": ["I'm sorry, I didn't understand. Could you please rephrase your request?"],
}
def generate_response(message, domain):
    
    message = message.lower()

    if domain in responses:
        if message in responses[domain]:
            return random.choice(responses[domain][message])
        else:
            return random.choice(responses[domain]["default"])
    else:
        if message in responses:
            return random.choice(responses[message])
        else:
            return random.choice(responses["default"])
        
domain = "restaurant"

print("Welcome to our restaurant. How can I assist you?")

while True:
    message = input("You: ")

    response = generate_response(message, domain)

    print("Bot: ", response)

# %%
import re as regx
# Based on regular Expression
# Define the responses for each pattern
responses = {
    r"hi|hello|hey": ["Welcome to our restaurant! How can I assist you?"],
    r"menu": ["Our menu includes a variety of dishes, such as burgers, pizzas, and salads. Would you like me to recommend anything?"],
    r"recommendation": ["Based on your preferences, I would recommend our special burger with fries and a drink."],
    r"reservation": ["Sure, let me check availability. How many people will be dining and what time would you like to make a reservation for?"],
    r"hours": ["We're open from 11am to 10pm every day."],
    r"location|directions": ["We're located at 123 Main Street in Nashik. Can I help with directions?"],
    r"thanks|thank you": ["You're welcome! Enjoy your meal."],
    r"food|dishes": ["We use fresh ingredients in all of our dishes to ensure the best quality and taste."],
    r"drinks": ["We offer a variety of non-alcoholic and alcoholic drinks, including beer, wine, and cocktails."],
    r"dessert|sweets": ["Don't forget to save room for dessert! Our most popular desserts are the chocolate cake and the cheesecake."],
    r"vegetarian|veggie": ["We have several vegetarian options on our menu, including a veggie burger and a garden salad."],
    r"gluten-free": ["We also have gluten-free options available, such as a gluten-free pizza crust and a quinoa salad."],
   r"burgers": ["Classic Burger - $10.99", "Cheeseburger - $11.99", "Bacon Burger - $12.99", "Mushroom Swiss Burger - $13.99"],
    r"pizza": ["Pepperoni Pizza - $14.99, Margherita Pizza - $15.99, Hawaiian Pizza - $16.99, BBQ Chicken Pizza - $17.99"],
    r"salads": ["Caesar Salad - $8.99", "Greek Salad - $9.99", "Cobb Salad - $10.99", "Spinach Salad - $11.99"],
    r"desserts": ["Chocolate Cake - $6.99", "Cheesecake - $7.99", "Ice Cream Sundae - $5.99", "Fruit Tart - $8.99"],
    r"drinks": ["Soda - $2.99", "Iced Tea - $3.99", "Lemonade - $4.99", "Coffee - $2.99", "Beer - $5.99", "Wine - $8.99", "Cocktails - $9.99"]
}

# Match the user input with the corresponding response
def match_response(user_input):
    for pattern, response in responses.items():
        if regx.search(pattern, user_input, regx.IGNORECASE):
            return response
    return ["I'm sorry, I didn't understand your request. Please try again."]

domain = "restaurant"

print("Welcome to our restaurant. How can I assist you?")

while True:
    user_input = input("You: ")
    response = match_response(user_input)
    print("Bot: ",response[0])
# Out:
# Welcome to our restaurant. How can I assist you?
# You: hello
# Bot:  Welcome to our restaurant! How can I assist you?
# You: give me menu
# Bot:  Our menu includes a variety of dishes, such as burgers, pizzas, and salads. Would you like me to recommend anything?
# You: what type of food you offers?
# Bot:  We use fresh ingredients in all of our dishes to ensure the best quality and taste.
# You: what is the price of pizza
# Bot:  Pepperoni Pizza - $14.99, Margherita Pizza - $15.99, Hawaiian Pizza - $16.99, BBQ Chicken Pizza - $17.99
# You: thanks bot
# Bot:  You're welcome! Enjoy your meal.
